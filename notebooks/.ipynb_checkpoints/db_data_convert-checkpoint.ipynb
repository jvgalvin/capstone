# %%
#!pip install -r data/requirements.txt

# %%
import json
import numpy as np
import pandas as pd

# %%
def write_to_json_file(input_obj, file_name):
    json_object = input_obj.to_json(orient="records")
 
    # Writing to sample.json
    with open(file_name, "w") as outfile:
        outfile.write(json_object)

# %% [markdown]
# # Read db_data.csv File

# %%
df = pd.read_csv("data/db_data.csv")

df.rename(columns = {'PTID':'patient_id'}, inplace = True)

df = df.drop('AD_dx_in_5_yrs', axis=1)

df.insert(loc = 1, column = 'ad_probability', value = -1)

# Write full DF as JSON
write_to_json_file(df, "data/db_data_full.json")

df.head()
# Out:
#    patient_id  ad_probability  Diagnosis_at_Baseline   Age  Gender  \
# 0  022_S_0004              -1                      1  67.5       1
# 1  011_S_0005              -1                      0  73.7       1
# 2  100_S_0006              -1                      1  80.4       0
# 3  022_S_0014              -1                      0  78.5       0
# 4  100_S_0015              -1                      0  80.8       1
#
#    Years_of_Education  Ethnicity  Race  APOE4  MMSE  ...  \
# 0                  10          0     2    0.0  27.0  ...
# 1                  16          1     2    0.0  29.0  ...
# 2                  13          1     2    0.0  25.0  ...
# 3                  12          0     2    0.0  29.0  ...
# 4                  18          1     2    1.0  29.0  ...
#
#    geodesic.depth..mean.1030  travel.depth..SD.2034  \
# 0                   0.188602               5.364973
# 1                   0.220386               7.239865
# 2                   0.200867               6.128271
# 3                   0.169551               5.564243
# 4                   0.209957               4.818484
#
#    geodesic.depth..skew.2030  FreeSurfer.thickness..kurtosis.2029  \
# 0                  -0.168525                             0.188154
# 1                  -0.389985                            -0.559673
# 2                  -0.417992                            -0.879520
# 3                  -0.327059                             0.178000
# 4                  -0.489000                            -0.206469
#
#    travel.depth..SD.2012  geodesic.depth..median.2014  \
# 0               5.273954                     0.037721
# 1               5.162919                     0.046602
# 2               5.031515                     0.054069
# 3               5.166338                     0.040544
# 4               5.316625                     0.037626
#
#    FreeSurfer.thickness..75..2013  travel.depth..75..1013  \
# 0                        2.366985                5.446182
# 1                        2.260876                8.057920
# 2                        1.969230                7.236270
# 3                        2.176968                4.954050
# 4                        1.869886                6.345510
#
#    FreeSurfer.convexity..kurtosis.2017  geodesic.depth..SD.1030
# 0                            -1.224131                 0.182104
# 1                            -0.376034                 0.182483
# 2                            -0.805533                 0.185645
# 3                            -0.874390                 0.177697
# 4                            -0.776811                 0.192963
#
# [5 rows x 160 columns]

# %% [markdown]
# # Filter Data and Convert to JSON

# %%
# Split DFs into objects
df_1 = df.iloc[:,0:61]
df_2 = df.iloc[:,61:117]
df_3 = df.iloc[:,117:]


# Save as JSON arrays
write_to_json_file(df_1, "data/db_data_converted_part_1.json")
write_to_json_file(df_2, "data/db_data_converted_part_2.json")
write_to_json_file(df_3, "data/db_data_converted_part_3.json")

print(df_1.head())
print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
print(df_2.head())
print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
print(df_3.head())
print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
# Out:
#    patient_id  ad_probability  Diagnosis_at_Baseline   Age  Gender  \
# 0  022_S_0004              -1                      1  67.5       1
# 1  011_S_0005              -1                      0  73.7       1
# 2  100_S_0006              -1                      1  80.4       0
# 3  022_S_0014              -1                      0  78.5       0
# 4  100_S_0015              -1                      0  80.8       1
#
#    Years_of_Education  Ethnicity  Race  APOE4  MMSE  ...  \
# 0                  10          0     2    0.0  27.0  ...
# 1                  16          1     2    0.0  29.0  ...
# 2                  13          1     2    0.0  25.0  ...
# 3                  12          0     2    0.0  29.0  ...
# 4                  18          1     2    1.0  29.0  ...
#
#    FreeSurfer.convexity..75..1017  FreeSurfer.convexity..median.1013  \
# 0                        0.055770                          -0.312247
# 1                       -0.006824                          -0.196456
# 2                        0.229847                          -0.076990
# 3                        0.136521                          -0.080071
# 4                        0.188573                          -0.209377
#
#    FreeSurfer.convexity..kurtosis.2016  geodesic.depth..75..1024  \
# 0                            -0.660431                  0.259387
# 1                            -0.922155                  0.286849
# 2                            -0.981143                  0.283925
# 3                            -0.721494                  0.254608
# 4                            -0.984730                  0.278416
#
#    travel.depth..25..1017  FreeSurfer.thickness..skew.1007  \
# 0                0.382777                         0.829816
# 1                0.171497                         0.863331
# 2                0.154557                         0.919417
# 3                0.352902                         0.794212
# 4                0.294301                         1.254718
#
#    travel.depth..kurtosis.2003  FreeSurfer.convexity..kurtosis.2030  \
# 0                    -1.016573                            -1.044846
# 1                    -1.121557                            -0.957149
# 2                    -1.240084                            -1.005111
# 3                    -1.384778                            -0.943277
# 4                    -1.198122                            -0.825540
#
#    FreeSurfer.convexity..kurtosis.1005  geodesic.depth..median.1013
# 0                            -1.060184                     0.070393
# 1                            -0.813067                     0.139627
# 2                            -0.446488                     0.094218
# 3                            -0.448297                     0.074226
# 4                            -0.600076                     0.078290
#
# [5 rows x 61 columns]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#    geodesic.depth..75..1034  geodesic.depth..kurtosis.2009  \
# 0                  0.713412                      -1.182161
# 1                  0.696999                      -1.315774
# 2                  0.651882                      -1.297753
# 3                  0.583386                      -1.313271
# 4                  0.687646                      -1.348501
#
#    geodesic.depth..75..1017  FreeSurfer.thickness..median.1017  \
# 0                  0.188890                           1.782379
# 1                  0.126664                           2.105852
# 2                  0.208474                           2.543583
# 3                  0.207584                           2.292389
# 4                  0.163146                           1.753147
#
#    travel.depth..25..1024  geodesic.depth..kurtosis.1009  \
# 0                0.839302                      -1.134683
# 1                1.437430                      -1.216571
# 2                1.776810                      -1.205771
# 3                0.525126                      -1.329353
# 4                1.213610                      -1.255712
#
#    FreeSurfer.thickness..kurtosis.2017  mean.curvature..kurtosis.2012  \
# 0                             0.365251                      -0.160234
# 1                            -0.796733                      -0.441499
# 2                            -1.147343                      -0.134150
# 3                            -0.816070                      -0.234284
# 4                            -0.637798                       0.020081
#
#    FreeSurfer.convexity..SD.1034  FreeSurfer.convexity..MAD.2016  ...  \
# 0                       0.443477                        0.235073  ...
# 1                       0.445078                        0.303032  ...
# 2                       0.541114                        0.276626  ...
# 3                       0.443955                        0.269030  ...
# 4                       0.467495                        0.219838  ...
#
#    FreeSurfer.convexity..mean.2012  travel.depth..kurtosis.2034  \
# 0                        -0.069144                    -0.898074
# 1                        -0.102282                    -1.006387
# 2                        -0.106397                    -1.023238
# 3                        -0.074083                    -0.983730
# 4                        -0.221003                    -0.698851
#
#    FreeSurfer.thickness..median.2017  mean.curvature..median.1005  \
# 0                           1.815721                     -3.03740
# 1                           2.175724                     -2.96960
# 2                           2.390156                     -3.07163
# 3                           2.359462                     -3.64379
# 4                           1.691822                     -3.52292
#
#    FreeSurfer.thickness..25..2025  geodesic.depth..kurtosis.1005  \
# 0                        1.754726                      -0.993131
# 1                        1.616884                      -0.852068
# 2                        1.912599                       0.190880
# 3                        1.739510                      -0.691764
# 4                        1.600962                      -0.976583
#
#    FreeSurfer.convexity..75..2016  FreeSurfer.thickness..median.2013  \
# 0                        0.094463                           1.878222
# 1                        0.264686                           1.817575
# 2                        0.182403                           1.533280
# 3                        0.267563                           1.587850
# 4                        0.104552                           1.499514
#
#    geodesic.depth..MAD.1013  FreeSurfer.thickness..mean.1017
# 0                  0.053672                         1.833638
# 1                  0.098975                         2.108059
# 2                  0.071634                         2.418964
# 3                  0.053589                         2.355576
# 4                  0.062142                         1.826098
#
# [5 rows x 56 columns]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#    FreeSurfer.thickness..skew.1017  geodesic.depth..25..1005  \
# 0                         0.600433                  0.023142
# 1                         0.120184                  0.029549
# 2                        -0.174754                  0.005401
# 3                         0.378708                  0.022288
# 4                         0.376854                  0.017184
#
#    FreeSurfer.thickness..MAD.2016  travel.depth..25..2022  \
# 0                        0.603640                0.614581
# 1                        0.669053                0.438948
# 2                        0.692196                0.541964
# 3                        0.548525                0.610506
# 4                        0.655343                0.826042
#
#    geodesic.depth..SD.2016  FreeSurfer.thickness..SD.2016  \
# 0                 0.076073                       0.800862
# 1                 0.102332                       0.866964
# 2                 0.086416                       0.807151
# 3                 0.106933                       0.704978
# 4                 0.082231                       0.784818
#
#    geodesic.depth..mean.2012  geodesic.depth..median.2030  \
# 0                   0.157896                     0.167719
# 1                   0.207438                     0.199448
# 2                   0.169243                     0.175272
# 3                   0.201067                     0.154019
# 4                   0.165669                     0.183017
#
#    FreeSurfer.convexity..skew.2014  FreeSurfer.convexity..SD.2031  ...  \
# 0                        -0.425421                       0.630360  ...
# 1                        -0.268174                       0.690048  ...
# 2                        -0.185433                       0.657024  ...
# 3                        -0.604089                       0.664543  ...
# 4                        -0.452969                       0.663332  ...
#
#    geodesic.depth..mean.1030  travel.depth..SD.2034  \
# 0                   0.188602               5.364973
# 1                   0.220386               7.239865
# 2                   0.200867               6.128271
# 3                   0.169551               5.564243
# 4                   0.209957               4.818484
#
#    geodesic.depth..skew.2030  FreeSurfer.thickness..kurtosis.2029  \
# 0                  -0.168525                             0.188154
# 1                  -0.389985                            -0.559673
# 2                  -0.417992                            -0.879520
# 3                  -0.327059                             0.178000
# 4                  -0.489000                            -0.206469
#
#    travel.depth..SD.2012  geodesic.depth..median.2014  \
# 0               5.273954                     0.037721
# 1               5.162919                     0.046602
# 2               5.031515                     0.054069
# 3               5.166338                     0.040544
# 4               5.316625                     0.037626
#
#    FreeSurfer.thickness..75..2013  travel.depth..75..1013  \
# 0                        2.366985                5.446182
# 1                        2.260876                8.057920
# 2                        1.969230                7.236270
# 3                        2.176968                4.954050
# 4                        1.869886                6.345510
#
#    FreeSurfer.convexity..kurtosis.2017  geodesic.depth..SD.1030
# 0                            -1.224131                 0.182104
# 1                            -0.376034                 0.182483
# 2                            -0.805533                 0.185645
# 3                            -0.874390                 0.177697
# 4                            -0.776811                 0.192963
#
# [5 rows x 43 columns]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# # Convert Three DFs to JSON Array

# %%
data = [] # This is a list

# Convert DF fragments into JSON array strings
json_str_1 = df_1.to_json(orient="records")
json_str_2 = df_2.to_json(orient="records")
json_str_3 = df_3.to_json(orient="records")

# Convert to arrays
json_1 = json.loads(json_str_1)
json_2 = json.loads(json_str_2)
json_3 = json.loads(json_str_3)

for i in range(len(df_1)):
    # Append list
    row = [json_1[i], json_2[i], json_3[i]]
    data.append(row)

#json_data = json.dumps(data) # Convert the dictionary to a JSON string
#write_to_json_file(json_data, "data/db_data_converted.json")

# Convert the dictionary to a JSON string
with open('data/db_data_converted.json', 'w') as fout:
    json.dump(data, fout)
